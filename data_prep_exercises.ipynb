# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd
import acquire as a
from requests import get
from bs4 import BeautifulSoup

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/carlodeleon/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/carlodeleon/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/carlodeleon/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/carlodeleon/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/carlodeleon/nltk_data...
# ...

# %% [markdown]
# ## Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
# - Lowercase everything
# - Normalize unicode characters
# - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
def basic_clean(string):
    '''
    Lower-cases everthing.
    Normalizes unicode characters.
    Replaces anything that is not a letter, number, or white-space or a single quote.
    '''
    
    # lower case all letters
    string = string.lower()
    
    # Normalize unicode characters
    string = unicodedata.normalize('NFKD', string).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    
    # Replace anything that is not alphanumeric, white-space, or a single quote
    string = re.sub(r"[^a-z0-9'\s]", '', string)
    
    return string

# %%
words = 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passengers could see the\
Northern Lights. The aircraft was flying from Reykjavik, Iceland to Manchester Airport in the UK. "Big thanks to \
the @easyJet pilot...who did a 360 flyby mid flight to make sure all passengers could see the...Northern Lights,"\
a passenger tweeted.'

# %%
basic_clean(words)
# Out:
# 'an easyjet pilot made a 360degree turn on monday night in a bid to ensure that passengers could see thenorthern lights the aircraft was flying from reykjavik iceland to manchester airport in the uk big thanks to the easyjet pilotwho did a 360 flyby mid flight to make sure all passengers could see thenorthern lightsa passenger tweeted'

# %% [markdown]
# ## Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
tokenizer = ToktokTokenizer()

# %%
tokenizer.tokenize(words)
# Out:
# ['An',
#  'easyJet',
#  'pilot',
#  'made',
#  'a',
#  '360-degree',
#  'turn',
#  'on',
#  'Monday',
#  'night',
#  'in',
#  'a',
#  'bid',
#  'to',
#  'ensure',
#  'that',
#  'passengers',
#  'could',
#  'see',
#  'theNorthern',
#  'Lights.',
#  'The',
#  'aircraft',
#  'was',
#  'flying',
#  'from',
#  'Reykjavik',
#  ',',
#  'Iceland',
#  'to',
#  'Manchester',
#  'Airport',
#  'in',
#  'the',
#  'UK.',
#  '"',
#  'Big',
#  'thanks',
#  'to',
#  'the',
#  '@easyJet',
#  'pilot',
#  '...',
#  'who',
#  'did',
#  'a',
#  '360',
#  'flyby',
#  'mid',
#  'flight',
#  'to',
#  'make',
#  'sure',
#  'all',
#  'passengers',
#  'could',
#  'see',
#  'the',
#  '...',
#  'Northern',
#  'Lights',
#  ',',
#  '"',
#  'a',
#  'passenger',
#  'tweeted',
#  '.']

# %%
def tokenize(string):
    '''
    Tokenize every thing.
    '''
    
    # Tokenizer object
    tokenizer = ToktokTokenizer()
    
    # Tokenize all them words
    all_them_words = tokenizer.tokenize(string, return_str=True)
    
    return all_them_words

# %%
tokenize(words)
# Out:
# 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passengers could see theNorthern Lights. The aircraft was flying from Reykjavik , Iceland to Manchester Airport in the UK. " Big thanks to the @easyJet pilot ... who did a 360 flyby mid flight to make sure all passengers could see the ... Northern Lights , " a passenger tweeted .'

# %% [markdown]
# ## Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(string):
    '''
    Gettting the stem of each word.
    '''
    
    # Stemmer object
    ps = nltk.porter.PorterStemmer()
    
    # Stem the words
    stems = [ps.stem(word) for word in string.split()]
    stemmed = ' '.join(stems)
    
    return stemmed

# %%
stem(words)
# Out:
# 'an easyjet pilot made a 360-degre turn on monday night in a bid to ensur that passeng could see thenorthern lights. the aircraft wa fli from reykjavik, iceland to manchest airport in the uk. "big thank to the @easyjet pilot...who did a 360 flybi mid flight to make sure all passeng could see the...northern lights,"a passeng tweeted.'

# %%
words
# Out:
# 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passengers could see theNorthern Lights. The aircraft was flying from Reykjavik, Iceland to Manchester Airport in the UK. "Big thanks to the @easyJet pilot...who did a 360 flyby mid flight to make sure all passengers could see the...Northern Lights,"a passenger tweeted.'

# %% [markdown]
# ## Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(string):
    '''
    Lemmatize the words.
    '''
    
    # Lemmetizer Object
    wnl = nltk.stem.WordNetLemmatizer()
    
     # Stem the words
    lemon = [wnl.lemmatize(word) for word in string.split()]
    lemons = ' '.join(lemon)
    
    return lemons

# %%
lemmatize(words)
# Out:
# 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passenger could see theNorthern Lights. The aircraft wa flying from Reykjavik, Iceland to Manchester Airport in the UK. "Big thanks to the @easyJet pilot...who did a 360 flyby mid flight to make sure all passenger could see the...Northern Lights,"a passenger tweeted.'

# %%
words
# Out:
# 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passengers could see theNorthern Lights. The aircraft was flying from Reykjavik, Iceland to Manchester Airport in the UK. "Big thanks to the @easyJet pilot...who did a 360 flyby mid flight to make sure all passengers could see the...Northern Lights,"a passenger tweeted.'

# %% [markdown]
# ## Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.  This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(string):
    
    '''
    Removes English stop words.
    '''
    
    # English stop words
    stopword_list = stopwords.words('english')
    
    # String that will have stop words removed.
    words = string
    
    # Remove stop words and join
    words_removed = [word for word in words.split() if word not in stopword_list]
    words_removed = ' '.join(words_removed)
    
    return words_removed

# %%
# Function Test
remove_stopwords(words)
# Out:
# 'An easyJet pilot made 360-degree turn Monday night bid ensure passengers could see theNorthern Lights. The aircraft flying Reykjavik, Iceland Manchester Airport UK. "Big thanks @easyJet pilot...who 360 flyby mid flight make sure passengers could see the...Northern Lights,"a passenger tweeted.'

# %%
# OG string
words
# Out:
# 'An easyJet pilot made a 360-degree turn on Monday night in a bid to ensure that passengers could see theNorthern Lights. The aircraft was flying from Reykjavik, Iceland to Manchester Airport in the UK. "Big thanks to the @easyJet pilot...who did a 360 flyby mid flight to make sure all passengers could see the...Northern Lights,"a passenger tweeted.'

# %%
def remove_stopwords(string, extra_words=[], exclude=[]):
    
    '''
    Removes English stop words.
    '''
    
    # English stop words
    stopword_list = stopwords.words('english')
    
    # Remove excluded words from list
    stopword_list = 
    
    # Add the extra words to the list
    stopword_list = stopword_list.union(set(extra_words))
    
    
    # String that will have stop words removed.
    words = string
    
    # Remove stop words and join
    words_removed = [word for word in words.split() if word not in stopword_list]
    words_removed = ' '.join(words_removed)
    
    return words_removed

# %% [markdown]
# ## Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
categories = ['business','sports','entertainment','technology']
news_df = a.get_news_articles(categories)

# %%
news_df
# Out:
# [{'category': 'business',
#   'title': 'All Adani stocks end higher for the first time since Hindenburg report',
#   'content': 'All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since the report by US short-seller Hindenburg Research in late January that accused the group of fraud. Adani Enterprises led the rally, advancing almost 15% as the group conducted investor meetings in Singapore and Hong Kong. Adani Transmission and Adani Power rose by the 5% daily limit.'},
#  {'category': 'business',
#   'title': "Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices",
#   'content': 'Hours after the central government raised the price of commercial LPG cylinders by ₹350.50 per unit and domestic LPG cylinders by ₹50 per unit, Union Minister Smriti Irani\'s old tweet from 2011 resurfaced on social media. Her tweet read, "50 rupee hike in LPG!!!!! [And] they call themselves Aam Aadmi ki Sarkar. What a shame!"\n\n'},
# ...

# %%
news_df = pd.read_json('news_articles.json')
news_df.head()
# Out:
#    category  \
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business
#
#                                                                                       title  \
# 0                    All Adani stocks end higher for the first time since Hindenburg report
# 1  Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices
# 2                   Indian-Americans Renjen, Subramaniam to be members of US Export Council
# 3                           Adani secures $3 bn credit from a sovereign wealth fund: Report
# 4                           We can score a century for progress: Gates on meeting Tendulkar
#
#                                                                                      content
# 0  All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since ...
# 1  Hours after the central government raised the price of commercial LPG cylinders by ₹35...
# ...

# %% [markdown]
# ## Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
codeup_df = a.get_blog_articles_json()

# %%
codeup_df = pd.read_json('blog_posts.json')
codeup_df
# Out:
#                                                                       title  \
# 0  Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 1            Black excellence in tech: Panelist Spotlight – Stephanie Jones
# 2               Black excellence in tech: Panelist Spotlight – James Cooper
# 3            Black excellence in tech: Panelist Spotlight – Jeanice Freeman
# 4                  Coding Bootcamp or Self-Learning? Which is Best for You?
# 5                         Codeup Among Top 58 Best Coding Bootcamps of 2023
#
#                                                                                      link  \
# 0                                    https://codeup.com/codeup-news/panelist-spotlight-4/
# 1  https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/
# 2     https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/
# ...

# %% [markdown]
# ## For each dataframe, produce the following columns:
# - **title** to hold the title
# - **original** to hold the original article/post content
# - **clean** to hold the normalized and tokenized original with the stopwords removed.
# - **stemmed** to hold the stemmed version of the cleaned data.
# - **lemmatized** to hold the lemmatized version of the cleaned data.

# %% [markdown]
# basic_clean(string)
#
# tokenize(string)
#
# stem(string)
#
# lemmatize(string)
#
# remove_stopwords(string)

# %% [markdown]
# ### News Dataframe

# %%
news_df.head(3)
# Out:
#    category  \
# 0  business
# 1  business
# 2  business
#
#                                                                                       title  \
# 0                    All Adani stocks end higher for the first time since Hindenburg report
# 1  Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices
# 2                   Indian-Americans Renjen, Subramaniam to be members of US Export Council
#
#                                                                                      content
# 0  All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since ...
# 1  Hours after the central government raised the price of commercial LPG cylinders by ₹35...
# 2  Indian-Americans Punit Renjen and Rajesh Subramaniam will be members of US President J...

# %%
# Rename content column
news_df = news_df.rename(columns={'content': 'og_content'})

# %%
orignal_content = news_df['og_content']

# %%
# For loop to clean rows
cleaned_rows = []
for row in orignal_content:
    clean = basic_clean(row)
    cleaned_rows.append(clean)

# %%
news_df['cleaned_content'] = cleaned_rows

# %%
news_df.head()
# Out:
#    category  \
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business
#
#                                                                                       title  \
# 0                    All Adani stocks end higher for the first time since Hindenburg report
# 1  Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices
# 2                   Indian-Americans Renjen, Subramaniam to be members of US Export Council
# 3                           Adani secures $3 bn credit from a sovereign wealth fund: Report
# 4                           We can score a century for progress: Gates on meeting Tendulkar
#
#                                                                                   og_content  \
# 0  All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since ...
# 1  Hours after the central government raised the price of commercial LPG cylinders by ₹35...
# ...

# %%
cleaned_content = news_df['cleaned_content']

# %%
# For loop for stems of wrds
stems_list = []

for word in cleaned_content:
    stems = stem(word)
    stems_list.append(stems)

# %%
news_df['stemmed'] = stems_list
news_df.head()
# Out:
#    category  \
# 0  business
# 1  business
# 2  business
# 3  business
# 4  business
#
#                                                                                       title  \
# 0                    All Adani stocks end higher for the first time since Hindenburg report
# 1  Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices
# 2                   Indian-Americans Renjen, Subramaniam to be members of US Export Council
# 3                           Adani secures $3 bn credit from a sovereign wealth fund: Report
# 4                           We can score a century for progress: Gates on meeting Tendulkar
#
#                                                                                   og_content  \
# 0  All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since ...
# 1  Hours after the central government raised the price of commercial LPG cylinders by ₹35...
# ...

# %%
# For loop to lemmatize all the words
lemons_list = []

for word in cleaned_content:
    lemons = lemmatize(word)
    lemons_list.append(lemons)

# %%
news_df['lemmatized'] = lemons_list
news_df.head(3)
# Out:
#    category  \
# 0  business
# 1  business
# 2  business
#
#                                                                                       title  \
# 0                    All Adani stocks end higher for the first time since Hindenburg report
# 1  Smriti Irani's 2011 tweet on LPG price hike resurfaces after rise in LPG cylinder prices
# 2                   Indian-Americans Renjen, Subramaniam to be members of US Export Council
#
#                                                                                   og_content  \
# 0  All 10 Adani Group stocks closed higher on Wednesday, the first such occurrence since ...
# 1  Hours after the central government raised the price of commercial LPG cylinders by ₹35...
# 2  Indian-Americans Punit Renjen and Rajesh Subramaniam will be members of US President J...
#
#                                                                              cleaned_content  \
# ...

# %% [markdown]
# ### Codeup Blog

# %%
codeup_df.head(3)
# Out:
#                                                                       title  \
# 0  Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 1            Black excellence in tech: Panelist Spotlight – Stephanie Jones
# 2               Black excellence in tech: Panelist Spotlight – James Cooper
#
#                                                                                      link  \
# 0                                    https://codeup.com/codeup-news/panelist-spotlight-4/
# 1  https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/
# 2     https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/
#
#   date_published  \
# 0   Feb 16, 2023
# 1   Feb 13, 2023
# 2   Feb 10, 2023
#
#                                                                                      content
# 0  \nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup i...
# ...

# %%
# Rename content column
codeup_df = codeup_df.rename(columns={'content': 'og_content'})

# %%
orignal_content = codeup_df['og_content']

# %%
# For loop to clean rows
cleaned_rows = []
for row in orignal_content:
    clean = basic_clean(row)
    cleaned_rows.append(clean)

# %%
# Create cleaned content column
codeup_df['cleaned_content'] = cleaned_rows
codeup_df.head(3)
# Out:
#                                                                       title  \
# 0  Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 1            Black excellence in tech: Panelist Spotlight – Stephanie Jones
# 2               Black excellence in tech: Panelist Spotlight – James Cooper
#
#                                                                                      link  \
# 0                                    https://codeup.com/codeup-news/panelist-spotlight-4/
# 1  https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/
# 2     https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/
#
#   date_published  \
# 0   Feb 16, 2023
# 1   Feb 13, 2023
# 2   Feb 10, 2023
#
#                                                                                   og_content  \
# 0  \nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup i...
# ...

# %%
cleaned_content = codeup_df['cleaned_content']

# %%
# For loop for stems of words
stems_list = []

for word in cleaned_content:
    stems = stem(word)
    stems_list.append(stems)

# %%
# Create stems column
codeup_df['stemmed'] = stems_list
codeup_df.head(3)
# Out:
#                                                                       title  \
# 0  Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 1            Black excellence in tech: Panelist Spotlight – Stephanie Jones
# 2               Black excellence in tech: Panelist Spotlight – James Cooper
#
#                                                                                      link  \
# 0                                    https://codeup.com/codeup-news/panelist-spotlight-4/
# 1  https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/
# 2     https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/
#
#   date_published  \
# 0   Feb 16, 2023
# 1   Feb 13, 2023
# 2   Feb 10, 2023
#
#                                                                                   og_content  \
# 0  \nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup i...
# ...

# %%
# For loop to lemmatize all the words
lemons_list = []

for word in cleaned_content:
    lemons = lemmatize(word)
    lemons_list.append(lemons)

# %%
# Create lemmatized column
codeup_df['lemmatized'] = lemons_list
codeup_df.head(3)
# Out:
#                                                                       title  \
# 0  Black Excellence in Tech: Panelist Spotlight – Wilmarie De La Cruz Mejia
# 1            Black excellence in tech: Panelist Spotlight – Stephanie Jones
# 2               Black excellence in tech: Panelist Spotlight – James Cooper
#
#                                                                                      link  \
# 0                                    https://codeup.com/codeup-news/panelist-spotlight-4/
# 1  https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-stephanie-jones/
# 2     https://codeup.com/events/black-excellence-in-tech-panelist-spotlight-james-cooper/
#
#   date_published  \
# 0   Feb 16, 2023
# 1   Feb 13, 2023
# 2   Feb 10, 2023
#
#                                                                                   og_content  \
# 0  \nBlack excellence in tech: Panelist Spotlight – Wilmarie De La Cruz Mejia\n\nCodeup i...
# ...

# %% [markdown]
# ## Ask yourself:
# 1. If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#
# Lemmatize
#
# 2. If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#
# Lemmatize
#
# 3. If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?
#
# Stem
